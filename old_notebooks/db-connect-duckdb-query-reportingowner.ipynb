# %%
# !ls -la
# Out:
# total 903712
# drwxr-xr-x 1 root root      4096 Jul 18 22:40 .
# drwxr-xr-x 1 root root      4096 Jul 18 22:39 ..
# drwxr-xr-x 4 root root      4096 Jul 17 13:23 .config
# -rw-r--r-- 1 root root 925380608 Jul 18 22:21 lit_reportingowner.duckdb
# drwxr-xr-x 1 root root      4096 Jul 17 13:24 sample_data

# %%
# !curl -IL https://3253-machine-learning.s3.ca-central-1.amazonaws.com/lit_reportingowner.duckdb
# Out:
# HTTP/1.1 200 OK
# x-amz-id-2: QFXIgC2ums4Klr/PsoWUMSvAaxuPn/6g+Wfy/gI3zV77dgAWlFkFbAXVMskKAG67M6Siet4amtY=
# x-amz-request-id: MX7ST9CGN1DMSMP1
# Date: Fri, 19 Jul 2024 00:20:35 GMT
# Last-Modified: Thu, 18 Jul 2024 22:21:12 GMT
# ETag: "732d2ad75393efe30a7cf8f184e2c536-111"
# x-amz-server-side-encryption: AES256
# Accept-Ranges: bytes
# Content-Type: binary/octet-stream
# Server: AmazonS3
# Content-Length: 925380608

# %%
# !time wget --no-clobber https://3253-machine-learning.s3.ca-central-1.amazonaws.com/lit_reportingowner.duckdb
# Out:
# File ‘lit_reportingowner.duckdb’ already there; not retrieving.
#
#
# real	0m0.006s
# user	0m0.003s
# sys	0m0.002s

# %%
import duckdb

conn = duckdb.connect('lit_reportingowner.duckdb')
df = conn.sql('SELECT count(*) as total_count FROM lit_reportingowner').df()
df.head()
# Out:
#    total_count
# 0     12608897

# %%
q = "select * from lit_reportingowner limit 1000"
df_reportingowner = conn.sql(q).df()
df_reportingowner
# Out:
#                                                    URL       accessionNumber  \
# 0    https://www.sec.gov/Archives/edgar/data/100001...  0001233883-03-000002
# 1    https://www.sec.gov/Archives/edgar/data/100001...  0001233883-03-000006
# 2    https://www.sec.gov/Archives/edgar/data/100020...  0001181431-03-009603
# 3    https://www.sec.gov/Archives/edgar/data/100022...  0001012975-03-000139
# 4    https://www.sec.gov/Archives/edgar/data/100001...  0001233883-03-000004
# ..                                                 ...                   ...
# 995  https://www.sec.gov/Archives/edgar/data/101103...  0001011039-03-000004
# 996  https://www.sec.gov/Archives/edgar/data/101130...  0001181431-03-010460
# 997  https://www.sec.gov/Archives/edgar/data/101129...  0001140361-03-002206
# 998  https://www.sec.gov/Archives/edgar/data/101117...  0001181431-03-010044
# 999  https://www.sec.gov/Archives/edgar/data/101129...  0001140361-03-002212
#
# ...

# %%
df_reportingowner.columns
# Out:
# Index(['URL', 'accessionNumber', 'filingDate', 'filerCik', 'rptOwnerCik',
#        'rptOwnerName', 'rptOwnerStreet1', 'rptOwnerStreet2', 'rptOwnerCity',
#        'rptOwnerState', 'rptOwnerZipCode', 'rptOwnerStateDescription',
#        'isDirector', 'isOfficer', 'isTenPercentOwner', 'isOther',
#        'officerTitle', 'otherText'],
#       dtype='object')

# %%
df_reportingowner.describe()
# Out:
#          filingDate
# count  1.000000e+03
# mean   2.003056e+07
# std    4.870462e+01
# min    2.003050e+07
# 25%    2.003052e+07
# 50%    2.003053e+07
# 75%    2.003061e+07
# max    2.003063e+07
