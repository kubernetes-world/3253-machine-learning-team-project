# %%
# !ls -la
# Out:
# total 16
# drwxr-xr-x 1 root root 4096 Jul 19 20:31 .
# drwxr-xr-x 1 root root 4096 Jul 23 13:40 ..
# drwxr-xr-x 4 root root 4096 Jul 19 20:30 .config
# drwxr-xr-x 1 root root 4096 Jul 19 20:31 sample_data

# %%
# !curl -IL https://3253-machine-learning.s3.ca-central-1.amazonaws.com/lit_panel_aggr.duckdb
# Out:
# HTTP/1.1 200 OK
# x-amz-id-2: /UMeUw3nPNLu3SeBl+kOGHYc2p3owTypD956ImcVlH5TcC7E6zYdesBq5tTJ3dmMmZA8J24B+lqRVUX8JIZ98qrIpz6LyMPX
# x-amz-request-id: HFCN81GVK1THP3W1
# Date: Tue, 23 Jul 2024 13:41:31 GMT
# Last-Modified: Tue, 23 Jul 2024 13:39:21 GMT
# ETag: "27e820fd3a0291dfc8ae27170ad2afc4-26"
# x-amz-server-side-encryption: AES256
# Accept-Ranges: bytes
# Content-Type: binary/octet-stream
# Server: AmazonS3
# Content-Length: 216281088

# %%
# !time wget --no-clobber https://3253-machine-learning.s3.ca-central-1.amazonaws.com/lit_panel_aggr.duckdb
# Out:
# --2024-07-23 13:41:31--  https://3253-machine-learning.s3.ca-central-1.amazonaws.com/lit_panel_aggr.duckdb
# Resolving 3253-machine-learning.s3.ca-central-1.amazonaws.com (3253-machine-learning.s3.ca-central-1.amazonaws.com)... 3.5.253.19, 52.95.145.226, 3.5.253.171, ...
# Connecting to 3253-machine-learning.s3.ca-central-1.amazonaws.com (3253-machine-learning.s3.ca-central-1.amazonaws.com)|3.5.253.19|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 216281088 (206M) [binary/octet-stream]
# Saving to: ‘lit_panel_aggr.duckdb’
#
# lit_panel_aggr.duck 100%[===================>] 206.26M  43.5MB/s    in 5.4s
#
# 2024-07-23 13:41:36 (37.9 MB/s) - ‘lit_panel_aggr.duckdb’ saved [216281088/216281088]
#
#
# real	0m5.880s
# user	0m0.220s
# sys	0m0.644s

# %%
import duckdb

conn = duckdb.connect('lit_panel_aggr.duckdb')
df = conn.sql('SELECT count(*) as total_count FROM lit_panel_aggr').df()
df.head()
# Out:
#    total_count
# 0      8946704

# %%
conn.sql("DESCRIBE lit_panel_aggr").df()
# Out:
#                  column_name column_type null   key default extra
# 0        issuerTradingSymbol     VARCHAR  YES  None    None  None
# 1            accessionNumber     VARCHAR  YES  None    None  None
# 2            transactionCode     VARCHAR  YES  None    None  None
# 3              securityTitle     VARCHAR  YES  None    None  None
# 4            transactionType     VARCHAR  YES  None    None  None
# 5               count_star()      BIGINT  YES  None    None  None
# 6  _total_transaction_shares     HUGEINT  YES  None    None  None
# 7  _total_transaction_amount      DOUBLE  YES  None    None  None

# %%
conn.sql("SELECT * FROM lit_panel_aggr WHERE issuerTradingSymbol = 'AAPL' and transactionType = 'nonDerivativeTransaction'").df()
# Out:
#      issuerTradingSymbol       accessionNumber transactionCode securityTitle  \
# 0                   AAPL  0001181431-08-021471               S  Common Stock
# 1                   AAPL  0001181431-08-021472               S  Common Stock
# 2                   AAPL  0001181431-08-021469               S  Common Stock
# 3                   AAPL  0001181431-08-021473               S  Common Stock
# 4                   AAPL  0001181431-08-021470               S  Common Stock
# ...                  ...                   ...             ...           ...
# 1689                AAPL  0000320193-24-000019               M  Common Stock
# 1690                AAPL  0000320193-24-000071               G  Common Stock
# 1691                AAPL  0000320193-24-000075               S  Common Stock
# 1692                AAPL  0000320193-22-000074               F  Common Stock
# 1693                AAPL  0000320193-23-000017               M  Common Stock
#
# ...
