# %%
import psycopg2
from google.colab import userdata

conn = psycopg2.connect(
    host='machine-learning-3253-postgresql.cluster-cg8zwc77lit0.ca-central-1.rds.amazonaws.com',
    port=5432,
    user='postgres',
    password=userdata.get('postgres.password'),
    dbname='lit',
)

print(conn)
# Out:
# <connection object at 0x7c9cffe51a80; dsn: 'user=postgres password=xxx dbname=lit host=machine-learning-3253-postgresql.cluster-cg8zwc77lit0.ca-central-1.rds.amazonaws.com port=5432', closed: 0>

# %%
# docs: https://pandas.pydata.org/docs/reference/api/pandas.read_sql_query.html
import pandas.io.sql as sqlio
import pandas as pd
import timeit

def read_sql_query(q, conn):
    tic=timeit.default_timer()
    print(f"tic: {tic}")
    df = sqlio.read_sql_query(q, conn)
    toc=timeit.default_timer()
    print(f"toc: {toc}")
    print(f"benchmark: { toc - tic : .3f} seconds")
    return df

# %% [markdown]
# # Show full record count

# %%
q = "select count(*) from lit_panel;"
df = read_sql_query(q, conn)
display(df)
# Out:
# tic: 9832.15912422
# <ipython-input-2-106e10d2d09e>:9: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = sqlio.read_sql_query(q, conn)
# toc: 9869.055099359
# benchmark:  36.896 seconds
#       count
# 0  15863500

# %% [markdown]
# # Count of records with `transactionDates` in 2022

# %%
q = "select count(*) from lit_panel where transactionDate LIKE '2022-%'"
df = read_sql_query(q, conn)
display(df)
# Out:
# tic: 9869.075718459
# <ipython-input-2-106e10d2d09e>:9: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = sqlio.read_sql_query(q, conn)
# toc: 9882.552947893
# benchmark:  13.477 seconds
#     count
# 0  404925

# %% [markdown]
# # Count of records with `transactionDates` in 2023

# %%
q = "select count(*) from lit_panel where transactionDate LIKE '2023-%'"
df = read_sql_query(q, conn)
display(df)
# Out:
# tic: 9882.569457045
# <ipython-input-2-106e10d2d09e>:9: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = sqlio.read_sql_query(q, conn)
# toc: 9888.389405542
# benchmark:  5.820 seconds
#     count
# 0  393940

# %% [markdown]
# # Count of records with `transactionDates` in 2024

# %%
q = "select count(*) from lit_panel where transactionDate LIKE '2024-%'"
df = read_sql_query(q, conn)
display(df)
# Out:
# tic: 9888.405879258
# <ipython-input-2-106e10d2d09e>:9: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = sqlio.read_sql_query(q, conn)
# toc: 9894.580789271
# benchmark:  6.175 seconds
#     count
# 0  248953

# %% [markdown]
# # Show top 10 `accessionNumber` with maximum multiplicity

# %%
q = "select accessionNumber, count(*) from lit_panel group by accessionNumber order by count(*) desc limit 10;"
df = read_sql_query(q, conn)
display(df)
# Out:
# tic: 9894.597797757
# <ipython-input-2-106e10d2d09e>:9: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = sqlio.read_sql_query(q, conn)
# toc: 9956.715703249
# benchmark:  62.118 seconds
#         accessionnumber  count
# 0  0001019056-12-000683     60
# 1  0000891836-05-000274     60
# 2  0000950103-07-001386     60
# 3  0001019056-12-000682     60
# 4  0000038079-07-000094     60
# 5  0000033769-05-000062     60
# 6  0000950103-07-001385     60
# 7  0000070530-11-000003     60
# 8  0000950138-04-000532     60
# 9  0001019056-12-000685     60

# %%
q = "select * from lit_panel where accessionNumber='0001019056-12-000683';"
df = read_sql_query(q, conn)
display(df)
# Out:
# tic: 9956.738683887
# <ipython-input-2-106e10d2d09e>:9: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = sqlio.read_sql_query(q, conn)
# toc: 9957.15703073
# benchmark:  0.418 seconds
#                                                   url  acceptancedatetime  \
# 0   https://www.sec.gov/Archives/edgar/data/107017...      20120521180430
# 1   https://www.sec.gov/Archives/edgar/data/107017...      20120521180430
# 2   https://www.sec.gov/Archives/edgar/data/107017...      20120521180430
# 3   https://www.sec.gov/Archives/edgar/data/107017...      20120521180430
# 4   https://www.sec.gov/Archives/edgar/data/107017...      20120521180430
# 5   https://www.sec.gov/Archives/edgar/data/107017...      20120521180430
# 6   https://www.sec.gov/Archives/edgar/data/107017...      20120521180430
# ...

# %% [markdown]
# # Show `LIKE '%TSLA%'` records

# %%
q = "select * from lit_panel where issuerTradingSymbol LIKE '%TSLA%'"
df = read_sql_query(q, conn)
display(df)
# Out:
# tic: 9957.209783868
# <ipython-input-2-106e10d2d09e>:9: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = sqlio.read_sql_query(q, conn)
# toc: 9962.067490416
# benchmark:  4.858 seconds
#                                                     url  acceptancedatetime  \
# 0     https://www.sec.gov/Archives/edgar/data/123800...      20030627190938
# 1     https://www.sec.gov/Archives/edgar/data/124619...      20030630211934
# 2     https://www.sec.gov/Archives/edgar/data/120719...      20040608194659
# 3     https://www.sec.gov/Archives/edgar/data/107189...      20040715200133
# 4     https://www.sec.gov/Archives/edgar/data/107189...      20040715200133
# ...                                                 ...                 ...
# 6153  https://www.sec.gov/Archives/edgar/data/131860...      20240307200622
# ...

# %% [markdown]
# # Use `= 'TSLA'` instead... (indexed now!)

# %%
q = "select * from lit_panel where issuerTradingSymbol = 'TSLA'"
df = read_sql_query(q, conn)
display(df)
# Out:
# tic: 9962.106530816
# <ipython-input-2-106e10d2d09e>:9: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = sqlio.read_sql_query(q, conn)
# toc: 9962.562642573
# benchmark:  0.456 seconds
#                                                     url  acceptancedatetime  \
# 0     https://www.sec.gov/Archives/edgar/data/131491...      20100625155700
# 1     https://www.sec.gov/Archives/edgar/data/131491...      20100625155700
# 2     https://www.sec.gov/Archives/edgar/data/131491...      20100625155700
# 3     https://www.sec.gov/Archives/edgar/data/131491...      20100625155700
# 4     https://www.sec.gov/Archives/edgar/data/131860...      20100625155559
# ...                                                 ...                 ...
# 5164  https://www.sec.gov/Archives/edgar/data/131860...      20240605191639
# ...

# %%
# DON'T FORGET TO CLOSE CONNECTION AT THE END!
conn.close()

# %%
print(conn)
# Out:
# <connection object at 0x7c9cffe51a80; dsn: 'user=postgres password=xxx dbname=lit host=machine-learning-3253-postgresql.cluster-cg8zwc77lit0.ca-central-1.rds.amazonaws.com port=5432', closed: 1>

# %%
# !ls -la
# Out:
# total 16
# drwxr-xr-x 1 root root 4096 Jul 10 13:24 .
# drwxr-xr-x 1 root root 4096 Jul 11 22:59 ..
# drwxr-xr-x 4 root root 4096 Jul 10 13:23 .config
# drwxr-xr-x 1 root root 4096 Jul 10 13:24 sample_data
