# %%
# !time wget --no-clobber https://3253-machine-learning.s3.ca-central-1.amazonaws.com/market/SP100.zip

# !ls -lht

# !unzip SP100.zip -d market-data
# Out:
# --2024-08-01 15:49:08--  https://3253-machine-learning.s3.ca-central-1.amazonaws.com/market/SP100.zip
# Resolving 3253-machine-learning.s3.ca-central-1.amazonaws.com (3253-machine-learning.s3.ca-central-1.amazonaws.com)... 3.5.254.175, 16.12.4.50, 52.95.145.28, ...
# Connecting to 3253-machine-learning.s3.ca-central-1.amazonaws.com (3253-machine-learning.s3.ca-central-1.amazonaws.com)|3.5.254.175|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11405334 (11M) [application/zip]
# Saving to: ‘SP100.zip’
#
# SP100.zip           100%[===================>]  10.88M  15.1MB/s    in 0.7s
#
# 2024-08-01 15:49:09 (15.1 MB/s) - ‘SP100.zip’ saved [11405334/11405334]
#
#
# real	0m1.186s
# user	0m0.024s
# sys	0m0.045s
# total 11M
# -rw-r--r-- 1 root root  11M Jul 30 16:06 SP100.zip
# drwxr-xr-x 1 root root 4.0K Jul 30 13:24 sample_data
# Archive:  SP100.zip
#   inflating: market-data/output/historical-csv/AAPL.csv
#   inflating: market-data/output/historical-csv/ABBV.csv
#   inflating: market-data/output/historical-csv/ABT.csv
#   inflating: market-data/output/historical-csv/ACN.csv
#   inflating: market-data/output/historical-csv/ADBE.csv
#   inflating: market-data/output/historical-csv/AIG.csv
#   inflating: market-data/output/historical-csv/AMD.csv
#   inflating: market-data/output/historical-csv/AMGN.csv
#   inflating: market-data/output/historical-csv/AMT.csv
#   inflating: market-data/output/historical-csv/AMZN.csv
#   inflating: market-data/output/historical-csv/AVGO.csv
#   inflating: market-data/output/historical-csv/AXP.csv
#   inflating: market-data/output/historical-csv/BA.csv
#   inflating: market-data/output/historical-csv/BAC.csv
#   inflating: market-data/output/historical-csv/BK.csv
#   inflating: market-data/output/historical-csv/BKNG.csv
#   inflating: market-data/output/historical-csv/BLK.csv
#   inflating: market-data/output/historical-csv/BMY.csv
#   inflating: market-data/output/historical-csv/BRK.B.csv
#   inflating: market-data/output/historical-csv/C.csv
#   inflating: market-data/output/historical-csv/CAT.csv
#   inflating: market-data/output/historical-csv/CHTR.csv
#   inflating: market-data/output/historical-csv/CL.csv
#   inflating: market-data/output/historical-csv/CMCSA.csv
#   inflating: market-data/output/historical-csv/COF.csv
#   inflating: market-data/output/historical-csv/COP.csv
#   inflating: market-data/output/historical-csv/COST.csv
#   inflating: market-data/output/historical-csv/CRM.csv
#   inflating: market-data/output/historical-csv/CSCO.csv
#   inflating: market-data/output/historical-csv/CVS.csv
#   inflating: market-data/output/historical-csv/CVX.csv
#   inflating: market-data/output/historical-csv/DE.csv
#   inflating: market-data/output/historical-csv/DHR.csv
#   inflating: market-data/output/historical-csv/DIS.csv
#   inflating: market-data/output/historical-csv/DOW.csv
#   inflating: market-data/output/historical-csv/DUK.csv
#   inflating: market-data/output/historical-csv/EMR.csv
#   inflating: market-data/output/historical-csv/F.csv
#   inflating: market-data/output/historical-csv/FDX.csv
#   inflating: market-data/output/historical-csv/GD.csv
#   inflating: market-data/output/historical-csv/GE.csv
#   inflating: market-data/output/historical-csv/GILD.csv
#   inflating: market-data/output/historical-csv/GM.csv
#   inflating: market-data/output/historical-csv/GOOG.csv
#   inflating: market-data/output/historical-csv/GOOGL.csv
#   inflating: market-data/output/historical-csv/GS.csv
#   inflating: market-data/output/historical-csv/HD.csv
#   inflating: market-data/output/historical-csv/HON.csv
#   inflating: market-data/output/historical-csv/IBM.csv
#   inflating: market-data/output/historical-csv/INTC.csv
#   inflating: market-data/output/historical-csv/INTU.csv
#   inflating: market-data/output/historical-csv/JNJ.csv
#   inflating: market-data/output/historical-csv/JPM.csv
#   inflating: market-data/output/historical-csv/KHC.csv
#   inflating: market-data/output/historical-csv/KO.csv
#   inflating: market-data/output/historical-csv/LIN.csv
#   inflating: market-data/output/historical-csv/LLY.csv
#   inflating: market-data/output/historical-csv/LMT.csv
#   inflating: market-data/output/historical-csv/LOW.csv
#   inflating: market-data/output/historical-csv/MA.csv
#   inflating: market-data/output/historical-csv/MCD.csv
#   inflating: market-data/output/historical-csv/MDLZ.csv
#   inflating: market-data/output/historical-csv/MDT.csv
#   inflating: market-data/output/historical-csv/MET.csv
#   inflating: market-data/output/historical-csv/META.csv
#   inflating: market-data/output/historical-csv/MMM.csv
#   inflating: market-data/output/historical-csv/MO.csv
#   inflating: market-data/output/historical-csv/MRK.csv
#   inflating: market-data/output/historical-csv/MS.csv
#   inflating: market-data/output/historical-csv/MSFT.csv
#   inflating: market-data/output/historical-csv/NEE.csv
#   inflating: market-data/output/historical-csv/NFLX.csv
#   inflating: market-data/output/historical-csv/NKE.csv
#   inflating: market-data/output/historical-csv/NVDA.csv
#   inflating: market-data/output/historical-csv/ORCL.csv
#   inflating: market-data/output/historical-csv/PEP.csv
#   inflating: market-data/output/historical-csv/PFE.csv
#   inflating: market-data/output/historical-csv/PG.csv
#   inflating: market-data/output/historical-csv/PM.csv
#   inflating: market-data/output/historical-csv/PYPL.csv
#   inflating: market-data/output/historical-csv/QCOM.csv
#   inflating: market-data/output/historical-csv/RTX.csv
#   inflating: market-data/output/historical-csv/SBUX.csv
#   inflating: market-data/output/historical-csv/SCHW.csv
#   inflating: market-data/output/historical-csv/SO.csv
#   inflating: market-data/output/historical-csv/SPG.csv
#   inflating: market-data/output/historical-csv/T.csv
#   inflating: market-data/output/historical-csv/TGT.csv
#   inflating: market-data/output/historical-csv/TMO.csv
#   inflating: market-data/output/historical-csv/TMUS.csv
#   inflating: market-data/output/historical-csv/TSLA.csv
#   inflating: market-data/output/historical-csv/TXN.csv
#   inflating: market-data/output/historical-csv/UNH.csv
#   inflating: market-data/output/historical-csv/UNP.csv
#   inflating: market-data/output/historical-csv/UPS.csv
#   inflating: market-data/output/historical-csv/USB.csv
#   inflating: market-data/output/historical-csv/V.csv
#   inflating: market-data/output/historical-csv/VZ.csv
#   inflating: market-data/output/historical-csv/WFC.csv
#   inflating: market-data/output/historical-csv/WMT.csv
#   inflating: market-data/output/historical-csv/XOM.csv

# %%
symbols = !ls -A1 market-data/output/historical-csv | xargs -I {} basename -s '.csv' {}

print(f'symbols: {symbols}')
print(f'length: {len(symbols)}')
print(f'list type: {type(symbols)}')
# Out:
# symbols: ['AAPL', 'ABBV', 'ABT', 'ACN', 'ADBE', 'AIG', 'AMD', 'AMGN', 'AMT', 'AMZN', 'AVGO', 'AXP', 'BAC', 'BA', 'BK', 'BKNG', 'BLK', 'BMY', 'BRK.B', 'CAT', 'C', 'CHTR', 'CL', 'CMCSA', 'COF', 'COP', 'COST', 'CRM', 'CSCO', 'CVS', 'CVX', 'DE', 'DHR', 'DIS', 'DOW', 'DUK', 'EMR', 'F', 'FDX', 'GD', 'GE', 'GILD', 'GM', 'GOOG', 'GOOGL', 'GS', 'HD', 'HON', 'IBM', 'INTC', 'INTU', 'JNJ', 'JPM', 'KHC', 'KO', 'LIN', 'LLY', 'LMT', 'LOW', 'MA', 'MCD', 'MDLZ', 'MDT', 'META', 'MET', 'MMM', 'MO', 'MRK', 'MS', 'MSFT', 'NEE', 'NFLX', 'NKE', 'NVDA', 'ORCL', 'PEP', 'PFE', 'PG', 'PM', 'PYPL', 'QCOM', 'RTX', 'SBUX', 'SCHW', 'SO', 'SPG', 'T', 'TGT', 'TMO', 'TMUS', 'TSLA', 'TXN', 'UNH', 'UNP', 'UPS', 'USB', 'V', 'VZ', 'WFC', 'WMT', 'XOM']
# length: 101
# list type: <class 'IPython.utils.text.SList'>
