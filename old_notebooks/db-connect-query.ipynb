# %%
import duckdb

conn = duckdb.connect()
conn.install_extension('httpfs')
conn.load_extension('httpfs')

# %%
s3_uri = 's3://3253-machine-learning/layline-insidertrading.db'
https_url = 'https://3253-machine-learning.s3.ca-central-1.amazonaws.com/layline-insidertrading.db'

conn.execute(f"ATTACH '{s3_uri}' AS lit_db (READ_ONLY);")
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))

# %%
conn.sql("USE lit_db;")
conn.sql("SHOW TABLES;")
# Out:
# ┌────────────────────┐
# │        name        │
# │      varchar       │
# ├────────────────────┤
# │ lit_deriv          │
# │ lit_footnotes      │
# │ lit_header         │
# │ lit_nonderiv       │
# │ lit_panel          │
# │ lit_reportingowner │
# │ lit_signatures     │
# │ lit_submission     │
# └────────────────────┘

# %%
conn.sql("DESCRIBE lit_deriv;")
# Out:
# ┌─────────────────────────────────┬─────────────┬─────────┬─────────┬─────────┬─────────┐
# │           column_name           │ column_type │  null   │   key   │ default │  extra  │
# │             varchar             │   varchar   │ varchar │ varchar │ varchar │ varchar │
# ├─────────────────────────────────┼─────────────┼─────────┼─────────┼─────────┼─────────┤
# │ URL                             │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ accessionNumber                 │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ filingDate                      │ BIGINT      │ YES     │ NULL    │ NULL    │ NULL    │
# │ filerCik                        │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ transactionType                 │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ tableRow                        │ BIGINT      │ YES     │ NULL    │ NULL    │ NULL    │
# ...

# %%
conn.sql("DESCRIBE lit_footnotes;")
# Out:
# ┌─────────────────┬─────────────┬─────────┬─────────┬─────────┬─────────┐
# │   column_name   │ column_type │  null   │   key   │ default │  extra  │
# │     varchar     │   varchar   │ varchar │ varchar │ varchar │ varchar │
# ├─────────────────┼─────────────┼─────────┼─────────┼─────────┼─────────┤
# │ URL             │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ accessionNumber │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ filingDate      │ BIGINT      │ YES     │ NULL    │ NULL    │ NULL    │
# │ filerCik        │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ id              │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ content         │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# └─────────────────┴─────────────┴─────────┴─────────┴─────────┴─────────┘

# %%
conn.sql("DESCRIBE lit_header;")
# Out:
# ┌────────────────────────┬─────────────┬─────────┬─────────┬─────────┬─────────┐
# │      column_name       │ column_type │  null   │   key   │ default │  extra  │
# │        varchar         │   varchar   │ varchar │ varchar │ varchar │ varchar │
# ├────────────────────────┼─────────────┼─────────┼─────────┼─────────┼─────────┤
# │ URL                    │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ acceptanceDatetime     │ BIGINT      │ YES     │ NULL    │ NULL    │ NULL    │
# │ accessionNumber        │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ type                   │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ publicDocumentCount    │ BIGINT      │ YES     │ NULL    │ NULL    │ NULL    │
# │ period                 │ BIGINT      │ YES     │ NULL    │ NULL    │ NULL    │
# │ filingDate             │ BIGINT      │ YES     │ NULL    │ NULL    │ NULL    │
# │ dateOfFilingDateChange │ BIGINT      │ YES     │ NULL    │ NULL    │ NULL    │
# ...

# %%
conn.sql("DESCRIBE lit_nonderiv;")
# Out:
# ┌─────────────────────────────────┬─────────────┬─────────┬─────────┬─────────┬─────────┐
# │           column_name           │ column_type │  null   │   key   │ default │  extra  │
# │             varchar             │   varchar   │ varchar │ varchar │ varchar │ varchar │
# ├─────────────────────────────────┼─────────────┼─────────┼─────────┼─────────┼─────────┤
# │ URL                             │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ accessionNumber                 │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ filingDate                      │ BIGINT      │ YES     │ NULL    │ NULL    │ NULL    │
# │ filerCik                        │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ transactionType                 │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ tableRow                        │ BIGINT      │ YES     │ NULL    │ NULL    │ NULL    │
# ...

# %%
conn.sql("DESCRIBE lit_panel;")
# Out:
# ┌────────────────────────────┬─────────────┬─────────┬─────────┬─────────┬─────────┐
# │        column_name         │ column_type │  null   │   key   │ default │  extra  │
# │          varchar           │   varchar   │ varchar │ varchar │ varchar │ varchar │
# ├────────────────────────────┼─────────────┼─────────┼─────────┼─────────┼─────────┤
# │ URL                        │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ acceptanceDatetime         │ BIGINT      │ YES     │ NULL    │ NULL    │ NULL    │
# │ accessionNumber            │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ type                       │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ period                     │ BIGINT      │ YES     │ NULL    │ NULL    │ NULL    │
# │ filingDate                 │ BIGINT      │ YES     │ NULL    │ NULL    │ NULL    │
# │ dateOfFilingDateChange     │ BIGINT      │ YES     │ NULL    │ NULL    │ NULL    │
# ...

# %%
conn.sql("DESCRIBE lit_reportingowner;")
# Out:
# ┌──────────────────────────┬─────────────┬─────────┬─────────┬─────────┬─────────┐
# │       column_name        │ column_type │  null   │   key   │ default │  extra  │
# │         varchar          │   varchar   │ varchar │ varchar │ varchar │ varchar │
# ├──────────────────────────┼─────────────┼─────────┼─────────┼─────────┼─────────┤
# │ URL                      │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ accessionNumber          │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ filingDate               │ BIGINT      │ YES     │ NULL    │ NULL    │ NULL    │
# │ filerCik                 │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ rptOwnerCik              │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ rptOwnerName             │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ rptOwnerStreet1          │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# ...

# %%
conn.sql("DESCRIBE lit_signatures;")
# Out:
# ┌─────────────────┬─────────────┬─────────┬─────────┬─────────┬─────────┐
# │   column_name   │ column_type │  null   │   key   │ default │  extra  │
# │     varchar     │   varchar   │ varchar │ varchar │ varchar │ varchar │
# ├─────────────────┼─────────────┼─────────┼─────────┼─────────┼─────────┤
# │ URL             │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ accessionNumber │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ filingDate      │ BIGINT      │ YES     │ NULL    │ NULL    │ NULL    │
# │ filerCik        │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ signatureName   │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ signatureDate   │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# └─────────────────┴─────────────┴─────────┴─────────┴─────────┴─────────┘

# %%
conn.sql("DESCRIBE lit_submission;")
# Out:
# ┌──────────────────────────┬─────────────┬─────────┬─────────┬─────────┬─────────┐
# │       column_name        │ column_type │  null   │   key   │ default │  extra  │
# │         varchar          │   varchar   │ varchar │ varchar │ varchar │ varchar │
# ├──────────────────────────┼─────────────┼─────────┼─────────┼─────────┼─────────┤
# │ URL                      │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ acceptanceDatetime       │ BIGINT      │ YES     │ NULL    │ NULL    │ NULL    │
# │ accessionNumber          │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ filerCik                 │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ type                     │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ publicDocumentCount      │ BIGINT      │ YES     │ NULL    │ NULL    │ NULL    │
# │ period                   │ BIGINT      │ YES     │ NULL    │ NULL    │ NULL    │
# ...

# %%
res = conn.sql("SHOW TABLES;")
print(res)

# for table in res:
#     print(table)
#     res = conn.sql(f"SELECT count(*) FROM {table};")
#     print(res)
# Out:
# ┌────────────────────┐
# │        name        │
# │      varchar       │
# ├────────────────────┤
# │ lit_deriv          │
# │ lit_footnotes      │
# │ lit_header         │
# │ lit_nonderiv       │
# │ lit_panel          │
# │ lit_reportingowner │
# │ lit_signatures     │
# │ lit_submission     │
# └────────────────────┘

# %%
res = conn.sql("SELECT count(*) FROM lit_deriv;")
print(res)

res = conn.sql("SELECT count(*) FROM lit_footnotes;")
print(res)

res = conn.sql("SELECT count(*) FROM lit_header;")
print(res)

res = conn.sql("SELECT count(*) FROM lit_nonderiv;")
print(res)

res = conn.sql("SELECT count(*) FROM lit_panel;")
print(res)

res = conn.sql("SELECT count(*) FROM lit_reportingowner;")
print(res)

res = conn.sql("SELECT count(*) FROM lit_signatures;")
print(res)

res = conn.sql("SELECT count(*) FROM lit_submission;")
print(res)
# Out:
# ┌──────────────┐
# │ count_star() │
# │    int64     │
# ├──────────────┤
# │     10707760 │
# └──────────────┘
#
# ┌──────────────┐
# │ count_star() │
# │    int64     │
# ├──────────────┤
# │     21209878 │
# └──────────────┘
#
# ┌──────────────┐
# │ count_star() │
# │    int64     │
# ├──────────────┤
# │     10243636 │
# └──────────────┘
#
# ┌──────────────┐
# │ count_star() │
# │    int64     │
# ├──────────────┤
# │     22747631 │
# └──────────────┘
#
# ┌──────────────┐
# │ count_star() │
# │    int64     │
# ├──────────────┤
# │     15863500 │
# └──────────────┘
#
# ┌──────────────┐
# │ count_star() │
# │    int64     │
# ├──────────────┤
# │     12608897 │
# └──────────────┘
#
# ┌──────────────┐
# │ count_star() │
# │    int64     │
# ├──────────────┤
# │     11924290 │
# └──────────────┘
#
# ┌──────────────┐
# │ count_star() │
# │    int64     │
# ├──────────────┤
# │      9928775 │
# └──────────────┘

# %%
res = conn.sql("SELECT count(*) FROM lit_panel;")
print(res)

res = conn.sql("DESCRIBE lit_panel;")
print(res)
# Out:
# ┌──────────────┐
# │ count_star() │
# │    int64     │
# ├──────────────┤
# │     15863500 │
# └──────────────┘
#
# ┌────────────────────────────┬─────────────┬─────────┬─────────┬─────────┬─────────┐
# │        column_name         │ column_type │  null   │   key   │ default │  extra  │
# │          varchar           │   varchar   │ varchar │ varchar │ varchar │ varchar │
# ├────────────────────────────┼─────────────┼─────────┼─────────┼─────────┼─────────┤
# │ URL                        │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ acceptanceDatetime         │ BIGINT      │ YES     │ NULL    │ NULL    │ NULL    │
# │ accessionNumber            │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ type                       │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ period                     │ BIGINT      │ YES     │ NULL    │ NULL    │ NULL    │
# │ filingDate                 │ BIGINT      │ YES     │ NULL    │ NULL    │ NULL    │
# ...
